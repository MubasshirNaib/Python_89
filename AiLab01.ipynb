# %% [markdown]
# <a href="https://colab.research.google.com/github/MubasshirNaib/Python_89/blob/main/AiLab01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Mubassir")
name="cuet"
print(name)
# Out:
# Mubassir
# cuet

# %%
import sys
print(sys.version) # print version
# Out:
# 3.10.12 (main, Jun 11 2023, 05:26:28) [GCC 11.4.0]

# %%
x = input("Enter Your Name: ")
print("Your Name is : " + x + " Cse , Cuet 19")
# Out:
# Enter Your Name: Naib
# Your Name is : Naib Cse , Cuet 19

# %%
x=10
print(type(x))
x=10.5
print(type(x))
x=1+2j
print(type(x))
x="Naib"
print(type(x))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'str'>

# %%
x= input("Enter the First Number:")
y= input("Enter the Second Number")
z=int(x)+int(y)
print("Sum of the Number is " ,z)
# Out:
# Enter the First Number:5
# Enter the Second Number5
# Sum of the Number is  10

# %%
x=10
y=30
print(x,y)
print("This is " + str(x))
print("This is {} and this is {}".format(x,y))
print("This is {1} and this is {0}".format(x,y))
# Out:
# 10 30
# This is 10
# This is 10 and this is 30
# This is 30 and this is 10

# %%
a_integer,a_float,a_string = 100,210.10,"Mubasshir"
print(a_integer,a_float,a_string)

print("Integer: " + str(a_integer) + "Flaot: " + str(a_float) + "string: " + a_string)
print("Integer: {}, Float: {}, String:{}".format(a_integer,a_float,a_string))
# Out:
# 100 210.1 Mubasshir
# Integer: 100Flaot: 210.1string: Mubasshir
# Integer: 100, Float: 210.1, String:Mubasshir

# %%
str1='Mubasshir Naib '

print(str1)
print(str1[0])
print(str1[2:5])
print(str1[2:])
print(str1 * 2)
print(str1+"Test")
# Out:
# Mubasshir Naib
# M
# bas
# basshir Naib
# Mubasshir Naib Mubasshir Naib
# Mubasshir Naib Test

# %%
from IPython.utils.text import strip_email_quotes
str1="Hello World!"
str2=str1[6:11]
print(str2*20)
# Out:
# WorldWorldWorldWorldWorldWorldWorldWorldWorldWorldWorldWorldWorldWorldWorldWorldWorldWorldWorldWorld

# %%
print(str[2:2]) # kisu print korbae na

# %%
x,y=5,3
x//=y #floar kore x=x//y
#x= x/y
print(x)
x,y=5,2
print(x**y)#pow
# Out:
# 1.6666666666666667
# 25

# %%
a= 200
b= 200
if b > a:
  print("b is greater than a")
elif a==b:
  print("a,b both are equal")
else:
  print("a is greater than b")
  print("Cuet")
# Out:
# a,b both are equal

# %%
x=int(input("Enter the first Number:"))
y=int(input("Enter the second Number:"))
z=int(input("Enter the third Number:"))
if x>=y and x>=z:
  print( x,"is greater")
elif y>=z and y>=x:
  print( y,"is greater")
else:
  print( z," is greater")
# Out:
# Enter the first Number:20
# Enter the second Number:20
# Enter the third Number:10
# 20 is greater

# %%
x=input("Enter the first Number:")
y=input("Enter the second Number:")
z=input("Enter the third Number:")
if x>=y and x>=z:
  print( x,"is greater")
elif y>=z and y>=x:
  print( y,"is greater")
else:
  print( z," is greater")
# Out:
# Enter the first Number:10
# Enter the second Number:20
# Enter the third Number:10
# 20 is greater

# %% [markdown]
# This is **bold**.
# This is *italic*.
# This is ~strikethrough~
# $\sqrt{3x-1}+(1+x)^2$

# %% [markdown]
# **This is my First Program**
#
#
# ```
# ## This is formatted as code\
# ```
#
#
#  Link:[Cuet](https://www.cuet.ac.bd/)![01 (1).jpg](data:image/jpeg;base64,...)
